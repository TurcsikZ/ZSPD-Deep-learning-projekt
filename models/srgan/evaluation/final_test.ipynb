# %%
import evaluation as ev

# %%
model5_csv = "./Trained_models/saved_model5/test_loss_0.csv"

# %%
df5 = ev.load_csv(model5_csv)

# %%
index = []
for i in range(len(df5)):
    index.append(i)

# %%
model5 = ev.stats(df5)

# %%
model5
# Out:
# {'loss_D': 0.0007914589332357949,
#  'loss_G': 0.3988324125210873,
#  'ssim_avg': 0.38628810119149365,
#  'psnr_avg': 57.547781087249305,
#  'nrmse_avg': 0.5721773511844402}

# %%
ev.plot(index,df5)
