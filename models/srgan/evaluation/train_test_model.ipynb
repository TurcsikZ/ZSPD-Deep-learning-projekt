# %%
import evaluation as ev

# %%
model4_csv = "./Trained_models/saved_model4/pre_train/loss_0.csv"
model5_csv = "./Trained_models/saved_model5/pre_train/loss_0.csv"
model6_csv = "./Trained_models/saved_model6/pre_train/loss_0.csv"

# %%
df4 = ev.load_csv(model4_csv)
df5 = ev.load_csv(model5_csv)
df6 = ev.load_csv(model6_csv)

# %%
index = []
for i in range(len(df4)):
    index.append(i)

# %%
ev.plot(index,df4)

# %%
ev.plot(index,df5)

# %%
ev.plot(index,df6)

# %%
model4 = ev.stats(df4)
model5 = ev.stats(df5)
model6 = ev.stats(df6)

# %%
model4
# Out:
# {'loss_D': 0.02042924485492318,
#  'loss_G': 0.8006576544682499,
#  'ssim_avg': 0.2896914192188982,
#  'psnr_avg': 55.78229580440511,
#  'nrmse_avg': 0.6215230180562433}

# %%
model5
# Out:
# {'loss_D': 0.04970957730364492,
#  'loss_G': 0.871517182705326,
#  'ssim_avg': 0.23762550748132416,
#  'psnr_avg': 54.994076583137485,
#  'nrmse_avg': 0.6951991484398966}

# %%
model6
# Out:
# {'loss_D': 0.013076058887399253,
#  'loss_G': 0.9519269826593345,
#  'ssim_avg': 0.03420741940699458,
#  'psnr_avg': 52.28010509320065,
#  'nrmse_avg': 0.923853904109914}
