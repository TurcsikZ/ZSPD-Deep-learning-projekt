# %%
import evaluation as ev

# %%
model4_csv = "./Trained_models/saved_model4/val_loss_0.csv"
model5_csv = "./Trained_models/saved_model5/pre_train2/val_loss_0.csv"
model6_csv = "./Trained_models/saved_model6/val_loss_0.csv"

# %%
df4 = ev.load_csv(model4_csv)
df5 = ev.load_csv(model5_csv)
df6 = ev.load_csv(model6_csv)

# %%
index = []
for i in range(len(df4)):
    index.append(i)

# %%
model4 = ev.stats(df4)
model5 = ev.stats(df5)
model6 = ev.stats(df6)

# %%
model4
# Out:
# {'loss_D': 0.00408252582437435,
#  'loss_G': 0.4336247135209673,
#  'ssim_avg': 0.3682655932737216,
#  'psnr_avg': 56.848103354548144,
#  'nrmse_avg': 0.5843942263352013}

# %%
model5 # highest ssim_avg
# Out:
# {'loss_D': 0.0011999628875174846,
#  'loss_G': 0.4224151210930511,
#  'ssim_avg': 0.411018310800081,
#  'psnr_avg': 57.041390000212914,
#  'nrmse_avg': 0.5711486521305104}

# %%
model6
# Out:
# {'loss_D': 0.00024333402369155805,
#  'loss_G': 0.46545888449399525,
#  'ssim_avg': 0.2880705455218563,
#  'psnr_avg': 55.68944181883885,
#  'nrmse_avg': 0.6673685130531275}

# %%
ev.plot(index,df4)

# %%
ev.plot(index,df5)

# %%
ev.plot(index,df6)

# %%
ev.diff_plot(df4,df5,index)

# %%
ev.diff_plot(df4,df6,index)

# %%
ev.diff_plot(df5,df6,index)
